# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.226  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# Setup complete  (12 CPUs, 15.4 GB RAM, 326.4/395.6 GB disk)

# %%
import torch, gc
torch.cuda.empty_cache()
gc.collect()
# Out:
# 0

# %%
from ultralytics import YOLO

model = YOLO("yolov9t.pt")  # load a pretrained model (recommended for training)

model.train(data=r"D:\Codings\DMS\data.yaml", epochs=100, patience=100,)

# train the model
# Out:
# Ultralytics 8.3.226  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...

# %%
# # Run the following in case of trainig interruption or running out of GPU time. 
from ultralytics import YOLO

# # Load a model
model = YOLO(r"D:\Codings\DMS\runs\detect\train\weights\last.pt")
# load a partially trained model

# # Resume training
results = model.train(resume=True)
# Out:
# New https://pypi.org/project/ultralytics/8.3.227 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.226  Python-3.10.11 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce GTX 1650, 4096MiB)
# ...
